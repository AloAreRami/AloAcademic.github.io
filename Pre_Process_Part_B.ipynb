# %% [markdown]
# <a href="https://colab.research.google.com/github/AloAreRami/AloAcademic.github.io/blob/master/Pre_Process_Part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import zipfile

uploaded = files.upload()

# Code for the zip file
zip_filename = list(uploaded.keys())[0]

# How to unzip file
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall('.')

# How to read the file
df_30sec = pd.read_csv('features_30_sec.csv')

df_30sec.head()
# Out:
#      <input type="file" id="files-b034de80-4122-448d-802d-7749d60ae34b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b034de80-4122-448d-802d-7749d60ae34b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
import zipfile

uploaded = files.upload()
zip_filename = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall('.')

df_3sec = pd.read_csv('features_3_sec.csv')

df_3sec.head()
# Out:
#      <input type="file" id="files-81c43f2b-2a2a-4592-829a-a49f5ba18d98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81c43f2b-2a2a-4592-829a-a49f5ba18d98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
